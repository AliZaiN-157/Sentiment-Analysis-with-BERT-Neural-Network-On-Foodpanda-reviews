# %% [markdown]
# <a href="https://colab.research.google.com/github/AliZaiN-157/Sentiment-Analysis-with-BERT-Neural-Network-On-Foodpanda-reviews/blob/main/Sentiment_Analysis_with_BERT_Neural_Network_On_Foodpanda_reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers  --quiet
# Out:
#      |████████████████████████████████| 2.3MB 29.0MB/s
#      |████████████████████████████████| 901kB 54.8MB/s
#      |████████████████████████████████| 3.3MB 51.6MB/s

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import pandas as pd

# %%
tokenizer =AutoTokenizer.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

model = AutoModelForSequenceClassification.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

# %%
Foodpanda_reviews = pd.read_csv('Foodpanda_reviews.csv',error_bad_lines=False)
Foodpanda_reviews.head()
# Out:
# b'Skipping line 28: expected 2 fields, saw 3\n'
#    Unnamed: 0                                             review
# 0           0  Excellent ....I have a request though ....ther...
# 1           1                                          Excellent
# 2           2                                  They werent fresh
# 3           3  Everything was just awesome. But the sandwich ...
# 4           4  Pizza was not good . But sandwich and donut wa...

# %%
def sentiment_score(review):
    tokens = tokenizer.encode(review, return_tensors='pt')
    result = model(tokens)
    return int(torch.argmax(result.logits))+1

# %%
Foodpanda_reviews['sentiment'] = Foodpanda_reviews['review'].apply(lambda x: sentiment_score(x[:512]))

# %%
Foodpanda_reviews.head(50)
# Out:
#     Unnamed: 0                                             review  sentiment
# 0            0  Excellent ....I have a request though ....ther...          4
# 1            1                                          Excellent          5
# 2            2                                  They werent fresh          5
# 3            3  Everything was just awesome. But the sandwich ...          3
# 4            4  Pizza was not good . But sandwich and donut wa...          3
# 5            5                                        Really good          5
# 6            6                                       It's to good          3
# 7            7  Rider should keep change with them as we are a...          3
# 8            8  Took 3 hour received my order which was incomp...          1
# 9            9                                    Excellent fresh          5
# 10          10  Everything was on point \nFresh Boston Cream a...          5
# ...
